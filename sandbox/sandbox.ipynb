# %%
import numpy as np

# %%
sum(np.sin(list(range(24))))
# Out:
# 0.9798058094902635

# %%
np.degrees(np.arctan(sum(np.sin(np.radians(list(range(48, 72)))))/sum(np.cos(np.radians(list(range(48, 72)))))))
# Out:
# 59.5
